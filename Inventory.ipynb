# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Load a datasets

purches = pd.read_csv('/content/InvoicePurchases12312016.csv')
InvFinal = pd.read_csv('/content/EndInvFINAL12312016.csv')
sales = pd.read_csv('/content/SalesFINAL12312016.csv')
BegInv = pd.read_csv('/content/BegInvFINAL12312016.csv')
PurchasePrice = pd.read_csv('/content/2017PurchasePricesDec.csv')
PurchasesFinal = pd.read_csv('/content/PurchasesFINAL12312016.csv')
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47     None
# 1  2015-12-22  2016-02-21        15     140.55     8.57     None
# 2  2015-12-24  2016-02-16         5     106.60     4.61     None
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20     None
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20     None

# %%
# Column names
print(purches.columns)
print(InvFinal.columns)
print(sales.columns)
print(BegInv.columns)
print(PurchasePrice.columns)
print(PurchasesFinal.columns)
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')
# Index(['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size',
#        'onHand', 'Price', 'endDate'],
#       dtype='object')
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')
# Index(['InventoryId', 'Store', 'City', 'Brand', 'Description', 'Size',
#        'onHand', 'Price', 'startDate'],
#       dtype='object')
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
# 5 Head of InvoicePurchase data set

purches.head(5)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47     None
# 1  2015-12-22  2016-02-21        15     140.55     8.57     None
# 2  2015-12-24  2016-02-16         5     106.60     4.61     None
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20     None
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20     None
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['VendorNumber'].plot(kind='hist', bins=20, title='VendorNumber')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['PONumber'].plot(kind='hist', bins=20, title='PONumber')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Dollars'].plot(kind='hist', bins=20, title='Dollars')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('VendorName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('InvoiceDate').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('PODate').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('PayDate').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='VendorNumber', y='PONumber', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='PONumber', y='Quantity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='Quantity', y='Dollars', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='Dollars', y='Freight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['InvoiceDate']
#   ys = series['VendorNumber']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('InvoiceDate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('VendorName')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='VendorName', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('InvoiceDate')
# _ = plt.ylabel('VendorNumber')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['InvoiceDate']
#   ys = series['VendorNumber']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('InvoiceDate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InvoiceDate')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InvoiceDate', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('InvoiceDate')
# _ = plt.ylabel('VendorNumber')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['InvoiceDate']
#   ys = series['VendorNumber']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('InvoiceDate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PODate')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PODate', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('InvoiceDate')
# _ = plt.ylabel('VendorNumber')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['InvoiceDate']
#   ys = series['VendorNumber']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('InvoiceDate', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PayDate')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PayDate', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('InvoiceDate')
# _ = plt.ylabel('VendorNumber')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['VendorNumber'].plot(kind='line', figsize=(8, 4), title='VendorNumber')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['PONumber'].plot(kind='line', figsize=(8, 4), title='PONumber')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['Quantity'].plot(kind='line', figsize=(8, 4), title='Quantity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Dollars'].plot(kind='line', figsize=(8, 4), title='Dollars')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['InvoiceDate'].value_counts()
#     for x_label, grp in _df_20.groupby('VendorName')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('VendorName')
# _ = plt.ylabel('InvoiceDate')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['PODate'].value_counts()
#     for x_label, grp in _df_21.groupby('InvoiceDate')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('InvoiceDate')
# _ = plt.ylabel('PODate')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['PayDate'].value_counts()
#     for x_label, grp in _df_22.groupby('PODate')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('PODate')
# _ = plt.ylabel('PayDate')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['VendorName'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='VendorNumber', y='VendorName', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['InvoiceDate'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='VendorNumber', y='InvoiceDate', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['PODate'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='VendorNumber', y='PODate', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['PayDate'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='VendorNumber', y='PayDate', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# 5 Head of EndInvFinal Dataset

InvFinal.head(5)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2016-12-31
# 1  750mL       7  36.99  2016-12-31
# 2  750mL       7  38.99  2016-12-31
# 3  750mL       4  34.99  2016-12-31
# 4  750mL       7  14.99  2016-12-31
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['Brand'].plot(kind='hist', bins=20, title='Brand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['onHand'].plot(kind='hist', bins=20, title='onHand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_30.groupby('InventoryId').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32.plot(kind='scatter', x='Brand', y='onHand', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33.plot(kind='scatter', x='onHand', y='Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['onHand']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('onHand')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['onHand']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('onHand')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_37.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('Price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_38['Brand'].plot(kind='line', figsize=(8, 4), title='Brand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['onHand'].plot(kind='line', figsize=(8, 4), title='onHand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40['Price'].plot(kind='line', figsize=(8, 4), title='Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Description'].value_counts()
#     for x_label, grp in _df_41.groupby('InventoryId')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('InventoryId')
# _ = plt.ylabel('Description')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='Brand', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='Brand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_44['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_44, x='onHand', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_45['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_45, x='onHand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# 5 Head of SalesFinal Dataset

sales.head(5)
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice SalesDate  Volume  Classification  \
# 0              1         16.49       16.49  1/1/2016     750               1
# 1              2         32.98       16.49  1/2/2016     750               1
# 2              1         16.49       16.49  1/3/2016     750               1
# 3              1         14.49       14.49  1/8/2016     750               1
# 4              2         69.98       34.99  1/9/2016     375               1
#
#    ExciseTax  VendorNo                   VendorName
# 0       0.79     12546  JIM BEAM BRANDS COMPANY
# 1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2       0.79     12546  JIM BEAM BRANDS COMPANY
# 3       0.79     12546  JIM BEAM BRANDS COMPANY
# 4       0.79     12546  JIM BEAM BRANDS COMPANY
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_46['Brand'].plot(kind='hist', bins=20, title='Brand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_47['SalesQuantity'].plot(kind='hist', bins=20, title='SalesQuantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_48['SalesDollars'].plot(kind='hist', bins=20, title='SalesDollars')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['SalesPrice'].plot(kind='hist', bins=20, title='SalesPrice')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_50.groupby('InventoryId').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_51.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_52.groupby('Size').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_53.groupby('SalesDate').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_54.plot(kind='scatter', x='Brand', y='SalesQuantity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55.plot(kind='scatter', x='SalesQuantity', y='SalesDollars', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_56.plot(kind='scatter', x='SalesDollars', y='SalesPrice', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57.plot(kind='scatter', x='SalesPrice', y='Volume', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['SalesQuantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_58.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('SalesQuantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['SalesQuantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_59.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('SalesQuantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['SalesQuantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_60.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Size')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Size', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('SalesQuantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['SalesQuantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_61.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SalesDate')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SalesDate', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('SalesQuantity')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_62['Brand'].plot(kind='line', figsize=(8, 4), title='Brand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63['SalesQuantity'].plot(kind='line', figsize=(8, 4), title='SalesQuantity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_64['SalesDollars'].plot(kind='line', figsize=(8, 4), title='SalesDollars')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_65['SalesPrice'].plot(kind='line', figsize=(8, 4), title='SalesPrice')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Description'].value_counts()
#     for x_label, grp in _df_66.groupby('InventoryId')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('InventoryId')
# _ = plt.ylabel('Description')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Size'].value_counts()
#     for x_label, grp in _df_67.groupby('Description')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Description')
# _ = plt.ylabel('Size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['SalesDate'].value_counts()
#     for x_label, grp in _df_68.groupby('Size')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Size')
# _ = plt.ylabel('SalesDate')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_69['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_69, x='Brand', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_70['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_70, x='Brand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_71['Size'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_71, x='Brand', y='Size', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_72['SalesDate'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_72, x='Brand', y='SalesDate', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# 5 Head of BegInvFinal Dataset

BegInv.head(5)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01
# 2  750mL       6  36.99  2016-01-01
# 3  750mL       3  38.99  2016-01-01
# 4  750mL       6  34.99  2016-01-01
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_73['Brand'].plot(kind='hist', bins=20, title='Brand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_74['onHand'].plot(kind='hist', bins=20, title='onHand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_75['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_76.groupby('InventoryId').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_77.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_78.plot(kind='scatter', x='Brand', y='onHand', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_79.plot(kind='scatter', x='onHand', y='Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['onHand']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_80.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('onHand')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['onHand']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_81.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('onHand')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_82.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Store']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_83.sort_values('Store', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Store')
# _ = plt.ylabel('Price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_84['Brand'].plot(kind='line', figsize=(8, 4), title='Brand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_85['onHand'].plot(kind='line', figsize=(8, 4), title='onHand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_86['Price'].plot(kind='line', figsize=(8, 4), title='Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Description'].value_counts()
#     for x_label, grp in _df_87.groupby('InventoryId')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('InventoryId')
# _ = plt.ylabel('Description')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_88['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_88, x='Brand', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_89['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_89, x='Brand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_90['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_90, x='onHand', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_91['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_91, x='onHand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# 5 Head of2017PurchasePrice of Dataset

PurchasePrice.head(5)
# Out:
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.28          8320  SHAW ROSS INT L IMP LTD
# 1          28.67          1128  BROWN-FORMAN CORP
# 2          30.46          1128  BROWN-FORMAN CORP
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4          10.94          7245  PROXIMO SPIRITS INC.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_92['Brand'].plot(kind='hist', bins=20, title='Brand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_93['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_94['PurchasePrice'].plot(kind='hist', bins=20, title='PurchasePrice')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_95['VendorNumber'].plot(kind='hist', bins=20, title='VendorNumber')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_96.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_97.groupby('VendorName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_98.plot(kind='scatter', x='Brand', y='Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_99.plot(kind='scatter', x='Price', y='PurchasePrice', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_100.plot(kind='scatter', x='PurchasePrice', y='VendorNumber', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Brand']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_101.sort_values('Brand', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Brand')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Brand']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_102.sort_values('Brand', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('VendorName')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='VendorName', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Brand')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Brand']
#   ys = series['PurchasePrice']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_103.sort_values('Brand', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Brand')
# _ = plt.ylabel('PurchasePrice')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Brand']
#   ys = series['PurchasePrice']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_104.sort_values('Brand', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('VendorName')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='VendorName', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Brand')
# _ = plt.ylabel('PurchasePrice')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_105['Brand'].plot(kind='line', figsize=(8, 4), title='Brand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_106['Price'].plot(kind='line', figsize=(8, 4), title='Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_107['PurchasePrice'].plot(kind='line', figsize=(8, 4), title='PurchasePrice')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_108['VendorNumber'].plot(kind='line', figsize=(8, 4), title='VendorNumber')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['VendorName'].value_counts()
#     for x_label, grp in _df_109.groupby('Description')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Description')
# _ = plt.ylabel('VendorName')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_110['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_110, x='Brand', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_111['VendorName'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_111, x='Brand', y='VendorName', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_112['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_112, x='Price', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_113['VendorName'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_113, x='Price', y='VendorName', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# 5 Head of PurchasesFinal Dataset

PurchasesFinal.head(5)
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2015-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2016-01-02  2016-01-04  2016-02-16          35.71       6.0   214.26
# 1    2016-01-01  2016-01-07  2016-02-21           9.35       4.0    37.40
# 2    2016-01-02  2016-01-07  2016-02-21           9.41       5.0    47.05
# 3    2016-01-01  2016-01-07  2016-02-21           9.35       6.0    56.10
# 4    2016-01-02  2016-01-09  2016-02-16          21.32       5.0   106.60
#
#    Classification
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_114['Store'].plot(kind='hist', bins=20, title='Store')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_115['Brand'].plot(kind='hist', bins=20, title='Brand')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_116['VendorNumber'].plot(kind='hist', bins=20, title='VendorNumber')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_117['PONumber'].plot(kind='hist', bins=20, title='PONumber')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_118.groupby('InventoryId').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_119.groupby('Description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_120.groupby('Size').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_121.groupby('VendorName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_122.plot(kind='scatter', x='Store', y='Brand', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_123.plot(kind='scatter', x='Brand', y='VendorNumber', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_124.plot(kind='scatter', x='VendorNumber', y='PONumber', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_125.plot(kind='scatter', x='PONumber', y='PurchasePrice', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['PONumber']
#   ys = series['Store']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_126.sort_values('PONumber', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('InventoryId')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='InventoryId', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('PONumber')
# _ = plt.ylabel('Store')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['PONumber']
#   ys = series['Store']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_127.sort_values('PONumber', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('PONumber')
# _ = plt.ylabel('Store')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['PONumber']
#   ys = series['Store']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_128.sort_values('PONumber', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Size')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Size', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('PONumber')
# _ = plt.ylabel('Store')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['PONumber']
#   ys = series['Store']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_129.sort_values('PONumber', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('VendorName')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='VendorName', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('PONumber')
# _ = plt.ylabel('Store')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_130['Store'].plot(kind='line', figsize=(8, 4), title='Store')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_131['Brand'].plot(kind='line', figsize=(8, 4), title='Brand')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_132['VendorNumber'].plot(kind='line', figsize=(8, 4), title='VendorNumber')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_133['PONumber'].plot(kind='line', figsize=(8, 4), title='PONumber')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Description'].value_counts()
#     for x_label, grp in _df_134.groupby('InventoryId')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('InventoryId')
# _ = plt.ylabel('Description')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Size'].value_counts()
#     for x_label, grp in _df_135.groupby('Description')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Description')
# _ = plt.ylabel('Size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['VendorName'].value_counts()
#     for x_label, grp in _df_136.groupby('Size')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Size')
# _ = plt.ylabel('VendorName')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['PODate'].value_counts()
#     for x_label, grp in _df_137.groupby('VendorName')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('VendorName')
# _ = plt.ylabel('PODate')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_138['InventoryId'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_138, x='Store', y='InventoryId', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_139['Description'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_139, x='Store', y='Description', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_140['Size'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_140, x='Store', y='Size', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_141['VendorName'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_141, x='Store', y='VendorName', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Exploratory Data Analysis (EDA)

purches.isnull().sum()
# Out:
# VendorNumber    0
# VendorName      0
# InvoiceDate     0
# PONumber        0
# PODate          0
# PayDate         0
# Quantity        0
# Dollars         0
# Freight         0
# Approval        0
# dtype: int64

# %%
purches.shape
# Out:
# (5543, 10)

# %%
purches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5543 entries, 0 to 5542
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VendorNumber  5543 non-null   int64
#  1   VendorName    5543 non-null   object
#  2   InvoiceDate   5543 non-null   object
#  3   PONumber      5543 non-null   int64
#  4   PODate        5543 non-null   object
#  5   PayDate       5543 non-null   object
#  6   Quantity      5543 non-null   int64
#  7   Dollars       5543 non-null   float64
#  8   Freight       5543 non-null   float64
#  9   Approval      5543 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 433.2+ KB

# %%
purches['InvoiceDate'] = pd.to_datetime(purches['InvoiceDate'])

# %%
purches['Total Amount'] = purches['Dollars'] + purches['Freight']

# %%
purches.head(2)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval  Total Amount
# 0  2015-12-21  2016-02-16         6   214.26     3.47     None        217.73
# 1  2015-12-22  2016-02-21        15   140.55     8.57     None        149.12

# %%
purches['Approval'].unique()
# Out:
# array(['None', 'Frank Delahunt'], dtype=object)

# %%
drop = ['VendorNumber','PONumber','PODate']
purches.drop(drop, axis = 1, inplace =True)

# %%
High_purchases_item =purches.loc[purches['Quantity'].idxmax(), 'VendorName']
Quty = purches['Quantity'].max()
print("High Prchuse Vendor Name:- ",High_purchases_item,"Quantity :-", Quty)
# Out:
# High Prchuse Vendor Name:-  DIAGEO NORTH AMERICA INC    Quantity :- 141660

# %%
total_num_of_invoice = purches[purches['VendorName'] == 'DIAGEO NORTH AMERICA INC   '].shape[0]
print('Total Number Of Invoice:-',total_num_of_invoice)
Spend_Total_Amount =purches.loc[purches['VendorName'] == 'DIAGEO NORTH AMERICA INC   ','Total Amount'].sum()
print("Spend Total Amount:-",Spend_Total_Amount)
# Out:
# Total Number Of Invoice:- 55
# Spend Total Amount:- 51216828.92

# %%
Low_purchases_item =purches.loc[purches['Quantity'].idxmin(), 'VendorName']
Quty2 = purches['Quantity'].min()
print("Low Prchuse Vendor Name:- ",Low_purchases_item,"Quantity :-", Quty2)
# Out:
# Low Prchuse Vendor Name:-  HOOD RIVER DISTILLERS, Inc. Quantity :- 1

# %%
Spend_Total_Amount =purches.loc[purches['VendorName'] == 'HOOD RIVER DISTILLERS, Inc.','Total Amount'].sum()
print("Spend Total Amount:-",Spend_Total_Amount)
# Out:
# Spend Total Amount:- 24153.480000000003

# %%
# Sales FINAL

sales.head(5)
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice SalesDate  Volume  Classification  \
# 0              1         16.49       16.49  1/1/2016     750               1
# 1              2         32.98       16.49  1/2/2016     750               1
# 2              1         16.49       16.49  1/3/2016     750               1
# 3              1         14.49       14.49  1/8/2016     750               1
# 4              2         69.98       34.99  1/9/2016     375               1
#
#    ExciseTax  VendorNo                   VendorName
# 0       0.79     12546  JIM BEAM BRANDS COMPANY
# 1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2       0.79     12546  JIM BEAM BRANDS COMPANY
# 3       0.79     12546  JIM BEAM BRANDS COMPANY
# 4       0.79     12546  JIM BEAM BRANDS COMPANY

# %%
drop1 = ['InventoryId','VendorNo','Brand',]
sales.drop(drop1,axis=1,inplace=True)

# %%
sales
# Out:
#         Store                 Description        Size  SalesQuantity  \
# 0           1  Jim Beam w/2 Rocks Glasses       750mL              1
# 1           1  Jim Beam w/2 Rocks Glasses       750mL              2
# 2           1  Jim Beam w/2 Rocks Glasses       750mL              1
# 3           1  Jim Beam w/2 Rocks Glasses       750mL              1
# 4           1     Maker's Mark Combo Pack  375mL 2 Pk              2
# ...       ...                         ...         ...            ...
# 867459     76  Trinchero Main St Cab Svgn       750mL              1
# 867460     76  Trinchero Main St Cab Svgn       750mL              2
# 867461     76  Trinchero Main St Cab Svgn       750mL              2
# 867462     76  Trinchero Main St Cab Svgn       750mL              1
# 867463     76  Trinchero Main St Cab Svgn       750mL              1
#
#         SalesDollars  SalesPrice  SalesDate  Volume  Classification  \
# 0              16.49       16.49   1/1/2016     750               1
# 1              32.98       16.49   1/2/2016     750               1
# 2              16.49       16.49   1/3/2016     750               1
# 3              14.49       14.49   1/8/2016     750               1
# 4              69.98       34.99   1/9/2016     375               1
# ...              ...         ...        ...     ...             ...
# 867459          8.99        8.99   1/5/2016     750               2
# 867460         17.98        8.99   1/8/2016     750               2
# 867461         17.98        8.99  1/15/2016     750               2
# 867462          8.99        8.99  1/16/2016     750               2
# 867463          8.99        8.99  1/17/2016     750               2
#
#         ExciseTax                   VendorName
# 0            0.79  JIM BEAM BRANDS COMPANY
# 1            1.57  JIM BEAM BRANDS COMPANY
# 2            0.79  JIM BEAM BRANDS COMPANY
# 3            0.79  JIM BEAM BRANDS COMPANY
# 4            0.79  JIM BEAM BRANDS COMPANY
# ...           ...                          ...
# 867459       0.11  TRINCHERO FAMILY ESTATES
# 867460       0.22  TRINCHERO FAMILY ESTATES
# 867461       0.22  TRINCHERO FAMILY ESTATES
# 867462       0.11  TRINCHERO FAMILY ESTATES
# 867463       0.11                      TRINCHE
#
# [867464 rows x 11 columns]

# %%
sales['Total Amount'] = sales['SalesDollars'] + sales['ExciseTax']

# %%
High_sales_item =sales.loc[sales['SalesQuantity'].idxmax(), 'VendorName']
Quty3 = sales['SalesQuantity'].max()
print("High sales Vendor Name:- ",High_sales_item,"Quantity :-", Quty3)
# Out:
# High sales Vendor Name:-  E & J GALLO WINERY          Quantity :- 432

# %%
total_num_of_invoice3 = sales[sales['VendorName'] == 'E & J GALLO WINERY         '].shape[0]
print('Total Number Of Invoice:-',total_num_of_invoice3)
Spend_Total_Amount3 =sales.loc[sales['VendorName'] == 'E & J GALLO WINERY         ','Total Amount'].sum()
print("Spend Total Amount:-",Spend_Total_Amount3)
# Out:
# Total Number Of Invoice:- 54444
# Spend Total Amount:- 1336125.7399999998

# %%
Low_sales_item =sales.loc[sales['SalesQuantity'].idxmin(), 'VendorName']
Quty4 = sales['SalesQuantity'].min()
print("Low sales Vendor Name:- ",Low_sales_item,"Quantity :-", Quty4)
# Out:
# Low sales Vendor Name:-  JIM BEAM BRANDS COMPANY     Quantity :- 1

# %%
Spend_Total_Amount4 =sales.loc[sales['VendorName'] == 'JIM BEAM BRANDS COMPANY    ','Total Amount'].sum()
print("Spend Total Amount:-",Spend_Total_Amount4)
# Out:
# Spend Total Amount:- 2233905.4699999997

# %%
sales['Description'].unique()
# Out:
# array(['Jim Beam w/2 Rocks Glasses', "Maker's Mark Combo Pack",
#        'F Coppola Dmd Ivry Cab Svgn', ..., 'Casa Lapostolle Merlot',
#        'La Terre Merlot', 'Penfld Bin 407 Cab Svgn Ausl'], dtype=object)

# %%
sns.barplot(x='Total Amount', y='Description', data=sales)
# Out:
# <Axes: xlabel='Total Amount', ylabel='Description'>
